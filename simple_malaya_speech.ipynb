# %% [markdown]
# <a href="https://colab.research.google.com/github/Beast-Leon/RandomStuff/blob/main/simple_malaya_speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install malaya_speech
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 235 kB 63.4 MB/s
# ...
#      |████████████████████████████████| 120 kB 42.6 MB/s
# ...
#      |████████████████████████████████| 41 kB 188 kB/s
# ...
#   Created wheel for memoization: filename=memoization-0.4.0-py3-none-any.whl size=50467 sha256=e3830600cc38a3251254790a6bc26d10bfada4504d6eaf2decec0c5e86b7ecc3
#   Stored in directory: /root/.cache/pip/wheels/38/f7/65/161985e7311dd484a23b3a5c9149995dbf11db6cede602e7ef
# ...
#   Created wheel for python-speech-features: filename=python_speech_features-0.6-py3-none-any.whl size=5888 sha256=5eec414d29c94b6eef01854d56401e97e7f0f8b2922e800a6387edc59d3176b0
#   Stored in directory: /root/.cache/pip/wheels/b0/0e/94/28cd6afa3cd5998a63eef99fe31777acd7d758f59cf24839eb
# Successfully built memoization python-speech-features
# ...

# %%
import malaya_speech
import numpy as np
# Out:
# /usr/local/lib/python3.7/dist-packages/malaya_boilerplate/frozen_graph.py:36: UserWarning: Cannot import beam_search_ops from Tensorflow Addons, ['malaya.jawi_rumi.deep_model', 'malaya.phoneme.deep_model', 'malaya.rumi_jawi.deep_model', 'malaya.stem.deep_model'] will not available to use, make sure Tensorflow Addons version >= 0.12.0
#   f'Cannot import beam_search_ops from Tensorflow Addons, {USED_TREE} will not available to use, make sure Tensorflow Addons version >= 0.12.0'

# %%
model = malaya_speech.stt.deep_transducer(model = 'large-conformer-singlish')

# %%
audio_cut, sr = malaya_speech.load('audio_cut.wav')
#result = model.greedy_decoder([audio])[0]

# %%
import IPython.display as ipd
ipd.Audio(audio_cut, rate = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
result = model.greedy_decoder([audio_cut])[0]

# %%
result
# Out:
# 'you want taken garlic chicken ya you want ya ya its gonna be a big drinks we have the dog also we have a non we also have a like thing like thought sorry what wont drink is it'

# %%
result = model.greedy_decoder([audio_cut])[0]

# %%
result
# Out:
# 'you want taken garlic chicken ya you want chicken curry but of course there are nothing lemaks unique we have the dog also we have a non we also have a like thing like thought sorry what wont drink is it'

# %%
result = model.greedy_decoder([audio_cut])[0]

# %%
result
# Out:
# 'you want taken garlic chicken ya you all chicken curry but of course there are nothing lemaks unique we have the dog also we have a non we all have a like thing like thought sorry what wont drink is it'

# %%
result = model.greedy_decoder([audio_cut])[0]

# %%
result
# Out:
# 'you want taken garlic chicken ya you want ya ya its gonna be a big one drinks we have the dog also we have a non we all have a like thing like thought sorry what wont drink is it'
